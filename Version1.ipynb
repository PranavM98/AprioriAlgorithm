# %%
import matplotlib.pyplot as plt
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
import seaborn as sns
from mlxtend.frequent_patterns import association_rules
from mlxtend.frequent_patterns import apriori


# Importing the dataset
dataset = pd.read_csv('Admission_Predict_Ver1.1.csv')
type(dataset)



for col in dataset.columns:
    print (col)


df=dataset.drop(dataset[dataset.Admit<0.72].index)
df=df.drop(['Admit'],axis=1)



for index,rows in df.iterrows():
    if df.loc[index,'Research']==1:
        df.loc[index,'Research']='Research-1'
    else:
        df.loc[index,'Research']='Research-0'




for index, row in df.iterrows():

    if df.loc[index,'GRE_Score'] >=320:
        df.loc[index,'GRE_Score']='GRE-1'
    elif df.loc[index,'GRE_Score']<300:
        df.loc[index,'GRE_Score']='GRE-3'
    else:
        df.loc[index,'GRE_Score']='GRE-2'



df.groupby('GRE_Score').count()



for index, row in df.iterrows():

    if df.loc[index,'TOEFL_Score'] >=110:
        df.loc[index,'TOEFL_Score']='TOEFL-1'
    elif df.loc[index,'TOEFL_Score']<100:
        df.loc[index,'TOEFL_Score']='TOEFL-3'
    else:
        df.loc[index,'TOEFL_Score']='TOEFL-2'

df.groupby('TOEFL_Score').count()


for index, row in df.iterrows():

    if df.loc[index,'SOP']==4.5:
        df.loc[index,'SOP']=5
    elif df.loc[index,'SOP']==3.5:
        df.loc[index,'SOP']=4
    elif df.loc[index,'SOP']==2.5:
        df.loc[index,'SOP']=3
    elif df.loc[index,'SOP']==1.5:
        df.loc[index,'SOP']=2
    elif df.loc[index,'SOP']==0.5:
        df.loc[index,'SOP']=1
    else:
        continue

df.groupby('SOP').count()

for index, row in df.iterrows():

    if df.loc[index,'LOR']==4.5:
        df.loc[index,'LOR']=5
    elif df.loc[index,'LOR']==3.5:
        df.loc[index,'LOR']=4
    elif df.loc[index,'LOR']==2.5:
        df.loc[index,'LOR']=3
    elif df.loc[index,'LOR']==1.5:
        df.loc[index,'LOR']=2
    elif df.loc[index,'LOR']==0.5:
        df.loc[index,'LOR']=1
    else:
        continue

df.groupby('LOR').count()



for index,rows in df.iterrows():
    if df.loc[index,'SOP']==5:
        df.loc[index,'SOP']='SOP-5'

    elif df.loc[index,'SOP']==4:
        df.loc[index,'SOP']='SOP-4'

    elif df.loc[index,'SOP']==3:
        df.loc[index,'SOP']='SOP-3'

    elif df.loc[index,'SOP']==2:
        df.loc[index,'SOP']='SOP-2'

    else:
        df.loc[index,'SOP']='SOP-1'


for index,rows in df.iterrows():
    if df.loc[index,'LOR']==5:
        df.loc[index,'LOR']='LOR-5'

    elif df.loc[index,'LOR']==4:
        df.loc[index,'LOR']='LOR-4'

    elif df.loc[index,'LOR']==3:
        df.loc[index,'LOR']='LOR-3'

    elif df.loc[index,'LOR']==2:
        df.loc[index,'LOR']='LOR-2'

    else:
        df.loc[index,'LOR']='LOR-1'



for index,rows in df.iterrows():
    if df.loc[index,'CGPA']>6.5 and df.loc[index,'CGPA']<=7.0:
        df.loc[index,'CGPA']='CGPA:6.5-7.0'
    elif df.loc[index,'CGPA']>7.0 and df.loc[index,'CGPA']<=7.5:
        df.loc[index,'CGPA']='CGPA:7.25-7.5'
    elif df.loc[index,'CGPA']>7.5 and df.loc[index,'CGPA']<=8.0:
        df.loc[index,'CGPA']='CGPA:7.5-8.0'
    elif df.loc[index,'CGPA']>8.0 and df.loc[index,'CGPA']<=8.5:
        df.loc[index,'CGPA']='CGPA:8.0-8.5'
    elif df.loc[index,'CGPA']>8.5 and df.loc[index,'CGPA']<=9.0:
        df.loc[index,'CGPA']='CPGA:8.5-9.0'
    elif df.loc[index,'CGPA']>9.0 and df.loc[index,'CGPA']<=9.5:
        df.loc[index,'CGPA']='CGPA:9.0-9.5'
    elif df.loc[index,'CGPA']>9.5:
        df.loc[index,'CGPA']='CGPA:9.5+'
    

df.to_csv('datafinal.csv',index=False)
# Out:
# Serial_No
# GRE_Score
# TOEFL_Score
# University_Rating
# SOP
# LOR
# CGPA
# Research
# Admit

# %%
data5and4.count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7d3d750fd019> in <module>()
# ----> 1 data5and4.count()
#
# NameError: name 'data5and4' is not defined

# %%
data=pd.read_csv("datafinal.csv")

# %%
data.count()
# Out:
# Serial_No            264
# GRE_Score            264
# TOEFL_Score          264
# University_Rating    264
# SOP                  264
# LOR                  264
# CGPA                 264
# Research             264
# dtype: int64

# %%
records = []
for i in range(0,264):
    records.append([str(data.values[i,j]) for j in range(1,7)])

records=records[1:len(data)]

te = TransactionEncoder()
te_ary = te.fit(records).transform(records)
df5 = pd.DataFrame(te_ary, columns=te.columns_)

frequent_itemsets = apriori(df5, min_support=0.5, use_colnames=True)
frequent_itemsets=frequent_itemsets.sort_values(by='support',ascending=0)
frequent_itemsets
# Out:
#     support          itemsets
# 0  0.745247           (GRE-1)
# 1  0.653992         (TOEFL-1)
# 2  0.623574  (GRE-1, TOEFL-1)

# %%
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)
rules=rules.sort_values(by="confidence",ascending=0)
rules
# Out:
#   antecedents consequents  antecedent support  consequent support   support  \
# 1   (TOEFL-1)     (GRE-1)            0.653992            0.745247  0.623574
# 0     (GRE-1)   (TOEFL-1)            0.745247            0.653992  0.623574
#
#    confidence      lift  leverage  conviction
# 1    0.953488  1.279426  0.136188    5.477186
# 0    0.836735  1.279426  0.136188    2.119297

# %%
records
# Out:
# [['GRE-1', 'TOEFL-2', '4', 'SOP-4', 'LOR-5', 'CPGA:8.5-9.0'],
#  ['GRE-2', 'TOEFL-2', '3', 'SOP-3', 'LOR-4', 'CGPA:7.5-8.0'],
#  ['GRE-1', 'TOEFL-1', '3', 'SOP-4', 'LOR-3', 'CPGA:8.5-9.0'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-5', 'LOR-3', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-2', '3', 'SOP-3', 'LOR-4', 'CGPA:8.0-8.5'],
#  ['GRE-1', 'TOEFL-1', '4', 'SOP-4', 'LOR-5', 'CPGA:8.5-9.0'],
#  ['GRE-1', 'TOEFL-1', '4', 'SOP-4', 'LOR-5', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-5', 'LOR-5', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-5', 'LOR-5', 'CGPA:9.5+'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-4', 'LOR-4', 'CGPA:9.5+'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-5', 'LOR-5', 'CGPA:9.5+'],
#  ['GRE-1', 'TOEFL-2', '5', 'SOP-5', 'LOR-4', 'CPGA:8.5-9.0'],
#  ['GRE-1', 'TOEFL-2', '3', 'SOP-4', 'LOR-4', 'CGPA:8.0-8.5'],
#  ['GRE-1', 'TOEFL-1', '4', 'SOP-3', 'LOR-5', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-4', 'LOR-4', 'CGPA:9.5+'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-4', 'LOR-5', 'CGPA:9.5+'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-5', 'LOR-5', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '4', 'SOP-5', 'LOR-4', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-5', 'LOR-4', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-5', 'LOR-4', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-4', 'LOR-5', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-5', 'LOR-4', 'CGPA:9.5+'],
#  ['GRE-1', 'TOEFL-1', '3', 'SOP-4', 'LOR-5', 'CPGA:8.5-9.0'],
#  ['GRE-1', 'TOEFL-1', '4', 'SOP-3', 'LOR-4', 'CGPA:8.0-8.5'],
#  ['GRE-2', 'TOEFL-3', '3', 'SOP-3', 'LOR-5', 'CGPA:8.0-8.5'],
#  ['GRE-1', 'TOEFL-1', '4', 'SOP-4', 'LOR-3', 'CGPA:7.5-8.0'],
#  ['GRE-1', 'TOEFL-1', '4', 'SOP-4', 'LOR-3', 'CGPA:8.0-8.5'],
#  ['GRE-1', 'TOEFL-1', '4', 'SOP-5', 'LOR-4', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-5', 'LOR-5', 'CGPA:9.5+'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-5', 'LOR-5', 'CGPA:9.5+'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-5', 'LOR-5', 'CGPA:9.0-9.5'],
#  ['GRE-2', 'TOEFL-2', '4', 'SOP-5', 'LOR-4', 'CGPA:9.0-9.5'],
#  ['GRE-2', 'TOEFL-2', '3', 'SOP-3', 'LOR-5', 'CPGA:8.5-9.0'],
#  ['GRE-1', 'TOEFL-1', '2', 'SOP-2', 'LOR-4', 'CPGA:8.5-9.0'],
#  ['GRE-1', 'TOEFL-1', '3', 'SOP-3', 'LOR-3', 'CPGA:8.5-9.0'],
#  ['GRE-1', 'TOEFL-1', '4', 'SOP-5', 'LOR-5', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-5', 'LOR-5', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-4', 'LOR-5', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-5', 'LOR-5', 'CGPA:9.0-9.5'],
#  ['GRE-2', 'TOEFL-2', '4', 'SOP-5', 'LOR-4', 'CPGA:8.5-9.0'],
#  ['GRE-2', 'TOEFL-2', '3', 'SOP-5', 'LOR-4', 'CGPA:8.0-8.5'],
#  ['GRE-2', 'TOEFL-2', '4', 'SOP-5', 'LOR-4', 'CPGA:8.5-9.0'],
#  ['GRE-1', 'TOEFL-1', '3', 'SOP-4', 'LOR-4', 'CPGA:8.5-9.0'],
#  ['GRE-1', 'TOEFL-1', '4', 'SOP-5', 'LOR-5', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '3', 'SOP-4', 'LOR-4', 'CPGA:8.5-9.0'],
#  ['GRE-1', 'TOEFL-1', '3', 'SOP-4', 'LOR-3', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '4', 'SOP-5', 'LOR-5', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '4', 'SOP-4', 'LOR-5', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-5', 'LOR-5', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '2', 'SOP-4', 'LOR-4', 'CPGA:8.5-9.0'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-5', 'LOR-5', 'CGPA:9.5+'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-5', 'LOR-5', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '3', 'SOP-4', 'LOR-3', 'CGPA:9.0-9.5'],
#  ['GRE-2', 'TOEFL-1', '3', 'SOP-3', 'LOR-2', 'CPGA:8.5-9.0'],
#  ['GRE-1', 'TOEFL-1', '3', 'SOP-4', 'LOR-3', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-5', 'LOR-5', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-4', 'LOR-5', 'CGPA:9.5+'],
#  ['GRE-2', 'TOEFL-2', '5', 'SOP-5', 'LOR-5', 'CPGA:8.5-9.0'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-4', 'LOR-5', 'CPGA:8.5-9.0'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-4', 'LOR-4', 'CGPA:9.0-9.5'],
#  ['GRE-2', 'TOEFL-2', '4', 'SOP-4', 'LOR-4', 'CPGA:8.5-9.0'],
#  ['GRE-2', 'TOEFL-2', '3', 'SOP-5', 'LOR-4', 'CGPA:8.0-8.5'],
#  ['GRE-1', 'TOEFL-1', '2', 'SOP-5', 'LOR-3', 'CGPA:9.0-9.5'],
#  ['GRE-2', 'TOEFL-2', '1', 'SOP-4', 'LOR-4', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '2', 'SOP-4', 'LOR-3', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '2', 'SOP-5', 'LOR-4', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-4', 'LOR-4', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '4', 'SOP-5', 'LOR-4', 'CGPA:9.5+'],
#  ['GRE-1', 'TOEFL-1', '2', 'SOP-3', 'LOR-4', 'CPGA:8.5-9.0'],
#  ['GRE-1', 'TOEFL-1', '2', 'SOP-2', 'LOR-3', 'CPGA:8.5-9.0'],
#  ['GRE-2', 'TOEFL-2', '3', 'SOP-2', 'LOR-3', 'CGPA:8.0-8.5'],
#  ['GRE-1', 'TOEFL-1', '3', 'SOP-3', 'LOR-3', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '4', 'SOP-4', 'LOR-4', 'CGPA:9.5+'],
#  ['GRE-2', 'TOEFL-2', '2', 'SOP-4', 'LOR-3', 'CGPA:8.0-8.5'],
#  ['GRE-1', 'TOEFL-1', '4', 'SOP-4', 'LOR-4', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-5', 'LOR-5', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-5', 'LOR-5', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-2', '3', 'SOP-3', 'LOR-4', 'CPGA:8.5-9.0'],
#  ['GRE-1', 'TOEFL-2', '3', 'SOP-3', 'LOR-4', 'CPGA:8.5-9.0'],
#  ['GRE-2', 'TOEFL-2', '3', 'SOP-3', 'LOR-3', 'CPGA:8.5-9.0'],
#  ['GRE-1', 'TOEFL-1', '4', 'SOP-5', 'LOR-4', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-5', 'LOR-4', 'CPGA:8.5-9.0'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-4', 'LOR-5', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '4', 'SOP-4', 'LOR-5', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '4', 'SOP-4', 'LOR-5', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '4', 'SOP-4', 'LOR-4', 'CPGA:8.5-9.0'],
#  ['GRE-1', 'TOEFL-1', '4', 'SOP-5', 'LOR-4', 'CPGA:8.5-9.0'],
#  ['GRE-1', 'TOEFL-1', '4', 'SOP-5', 'LOR-5', 'CGPA:9.0-9.5'],
#  ['GRE-2', 'TOEFL-1', '3', 'SOP-4', 'LOR-4', 'CGPA:9.0-9.5'],
#  ['GRE-2', 'TOEFL-2', '3', 'SOP-3', 'LOR-3', 'CGPA:8.0-8.5'],
#  ['GRE-2', 'TOEFL-2', '3', 'SOP-3', 'LOR-3', 'CGPA:8.0-8.5'],
#  ['GRE-2', 'TOEFL-1', '3', 'SOP-4', 'LOR-4', 'CPGA:8.5-9.0'],
#  ['GRE-2', 'TOEFL-2', '2', 'SOP-3', 'LOR-4', 'CGPA:8.0-8.5'],
#  ['GRE-1', 'TOEFL-1', '4', 'SOP-5', 'LOR-5', 'CGPA:9.0-9.5'],
#  ['GRE-2', 'TOEFL-2', '3', 'SOP-4', 'LOR-3', 'CPGA:8.5-9.0'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-5', 'LOR-4', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-5', 'LOR-4', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-5', 'LOR-5', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-5', 'LOR-4', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-4', 'LOR-5', 'CPGA:8.5-9.0'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-5', 'LOR-4', 'CPGA:8.5-9.0'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-5', 'LOR-5', 'CGPA:9.5+'],
#  ['GRE-2', 'TOEFL-2', '3', 'SOP-4', 'LOR-3', 'CPGA:8.5-9.0'],
#  ['GRE-2', 'TOEFL-2', '2', 'SOP-3', 'LOR-4', 'CPGA:8.5-9.0'],
#  ['GRE-2', 'TOEFL-2', '2', 'SOP-3', 'LOR-3', 'CGPA:8.0-8.5'],
#  ['GRE-2', 'TOEFL-2', '2', 'SOP-4', 'LOR-3', 'CGPA:8.0-8.5'],
#  ['GRE-2', 'TOEFL-2', '3', 'SOP-4', 'LOR-5', 'CPGA:8.5-9.0'],
#  ['GRE-2', 'TOEFL-2', '3', 'SOP-3', 'LOR-3', 'CPGA:8.5-9.0'],
#  ['GRE-2', 'TOEFL-1', '2', 'SOP-4', 'LOR-3', 'CGPA:8.0-8.5'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-5', 'LOR-5', 'CGPA:9.5+'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-4', 'LOR-5', 'CGPA:9.5+'],
#  ['GRE-1', 'TOEFL-2', '4', 'SOP-5', 'LOR-4', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '4', 'SOP-5', 'LOR-4', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '4', 'SOP-5', 'LOR-5', 'CGPA:9.5+'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-5', 'LOR-5', 'CGPA:9.5+'],
#  ['GRE-1', 'TOEFL-1', '4', 'SOP-5', 'LOR-5', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-5', 'LOR-5', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '4', 'SOP-5', 'LOR-5', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-2', '4', 'SOP-4', 'LOR-4', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '4', 'SOP-3', 'LOR-4', 'CPGA:8.5-9.0'],
#  ['GRE-2', 'TOEFL-2', '3', 'SOP-4', 'LOR-4', 'CGPA:8.0-8.5'],
#  ['GRE-2', 'TOEFL-2', '3', 'SOP-4', 'LOR-4', 'CPGA:8.5-9.0'],
#  ['GRE-2', 'TOEFL-1', '3', 'SOP-4', 'LOR-4', 'CPGA:8.5-9.0'],
#  ['GRE-1', 'TOEFL-1', '4', 'SOP-5', 'LOR-4', 'CPGA:8.5-9.0'],
#  ['GRE-1', 'TOEFL-1', '4', 'SOP-3', 'LOR-3', 'CGPA:9.0-9.5'],
#  ['GRE-2', 'TOEFL-2', '3', 'SOP-4', 'LOR-5', 'CPGA:8.5-9.0'],
#  ['GRE-2', 'TOEFL-2', '3', 'SOP-4', 'LOR-3', 'CGPA:8.0-8.5'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-5', 'LOR-4', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-5', 'LOR-4', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '4', 'SOP-4', 'LOR-5', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-5', 'LOR-5', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '3', 'SOP-4', 'LOR-3', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '4', 'SOP-4', 'LOR-3', 'CGPA:9.0-9.5'],
#  ['GRE-2', 'TOEFL-2', '3', 'SOP-3', 'LOR-4', 'CPGA:8.5-9.0'],
#  ['GRE-1', 'TOEFL-1', '3', 'SOP-4', 'LOR-4', 'CPGA:8.5-9.0'],
#  ['GRE-1', 'TOEFL-1', '3', 'SOP-4', 'LOR-4', 'CPGA:8.5-9.0'],
#  ['GRE-1', 'TOEFL-2', '3', 'SOP-3', 'LOR-3', 'CPGA:8.5-9.0'],
#  ['GRE-1', 'TOEFL-1', '4', 'SOP-5', 'LOR-5', 'CGPA:9.5+'],
#  ['GRE-1', 'TOEFL-1', '4', 'SOP-4', 'LOR-5', 'CGPA:9.0-9.5'],
#  ['GRE-2', 'TOEFL-1', '4', 'SOP-4', 'LOR-5', 'CGPA:8.0-8.5'],
#  ['GRE-2', 'TOEFL-3', '3', 'SOP-4', 'LOR-4', 'CPGA:8.5-9.0'],
#  ['GRE-1', 'TOEFL-2', '3', 'SOP-4', 'LOR-5', 'CPGA:8.5-9.0'],
#  ['GRE-1', 'TOEFL-2', '4', 'SOP-5', 'LOR-5', 'CPGA:8.5-9.0'],
#  ['GRE-1', 'TOEFL-1', '4', 'SOP-5', 'LOR-5', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-2', '5', 'SOP-5', 'LOR-4', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '2', 'SOP-3', 'LOR-3', 'CPGA:8.5-9.0'],
#  ['GRE-2', 'TOEFL-2', '2', 'SOP-2', 'LOR-3', 'CGPA:8.0-8.5'],
#  ['GRE-2', 'TOEFL-2', '3', 'SOP-3', 'LOR-4', 'CGPA:8.0-8.5'],
#  ['GRE-1', 'TOEFL-1', '4', 'SOP-5', 'LOR-5', 'CGPA:9.0-9.5'],
#  ['GRE-2', 'TOEFL-2', '4', 'SOP-5', 'LOR-5', 'CGPA:8.0-8.5'],
#  ['GRE-2', 'TOEFL-2', '2', 'SOP-3', 'LOR-3', 'CGPA:8.0-8.5'],
#  ['GRE-1', 'TOEFL-1', '3', 'SOP-4', 'LOR-3', 'CPGA:8.5-9.0'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-5', 'LOR-5', 'CGPA:9.0-9.5'],
#  ['GRE-2', 'TOEFL-1', '3', 'SOP-4', 'LOR-5', 'CGPA:9.0-9.5'],
#  ['GRE-2', 'TOEFL-2', '3', 'SOP-4', 'LOR-4', 'CPGA:8.5-9.0'],
#  ['GRE-1', 'TOEFL-1', '3', 'SOP-3', 'LOR-3', 'CPGA:8.5-9.0'],
#  ['GRE-1', 'TOEFL-1', '4', 'SOP-5', 'LOR-5', 'CGPA:9.5+'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-4', 'LOR-4', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-5', 'LOR-4', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '5', 'SOP-5', 'LOR-5', 'CGPA:9.0-9.5'],
#  ['GRE-2', 'TOEFL-2', '4', 'SOP-5', 'LOR-5', 'CGPA:9.0-9.5'],
#  ['GRE-2', 'TOEFL-2', '3', 'SOP-4', 'LOR-4', 'CPGA:8.5-9.0'],
#  ['GRE-2', 'TOEFL-2', '3', 'SOP-4', 'LOR-4', 'CPGA:8.5-9.0'],
#  ['GRE-1', 'TOEFL-1', '3', 'SOP-4', 'LOR-5', 'CGPA:9.0-9.5'],
#  ['GRE-1', 'TOEFL-1', '3', 'SOP-5', 'LOR-5', 'CGPA:9.0-9.5']]

# %%
df5
# Out:
#          1      2      3      4      5  CGPA:7.5-8.0  CGPA:8.0-8.5  \
# 0    False  False  False   True  False         False         False
# 1    False  False   True  False  False          True         False
# 2    False  False   True  False  False         False         False
# 3    False  False  False  False   True         False         False
# 4    False  False   True  False  False         False          True
# 5    False  False  False   True  False         False         False
# 6    False  False  False   True  False         False         False
# 7    False  False  False  False   True         False         False
# 8    False  False  False  False   True         False         False
# 9    False  False  False  False   True         False         False
# 10   False  False  False  False   True         False         False
# 11   False  False  False  False   True         False         False
# 12   False  False   True  False  False         False          True
# 13   False  False  False   True  False         False         False
# 14   False  False  False  False   True         False         False
# 15   False  False  False  False   True         False         False
# 16   False  False  False  False   True         False         False
# 17   False  False  False   True  False         False         False
# 18   False  False  False  False   True         False         False
# 19   False  False  False  False   True         False         False
# 20   False  False  False  False   True         False         False
# 21   False  False  False  False   True         False         False
# 22   False  False   True  False  False         False         False
# 23   False  False  False   True  False         False          True
# 24   False  False   True  False  False         False          True
# 25   False  False  False   True  False          True         False
# 26   False  False  False   True  False         False          True
# 27   False  False  False   True  False         False         False
# 28   False  False  False  False   True         False         False
# 29   False  False  False  False   True         False         False
# ..     ...    ...    ...    ...    ...           ...           ...
# 233  False  False  False  False   True         False         False
# 234  False  False  False  False   True         False         False
# 235  False  False  False  False   True         False         False
# 236  False  False  False   True  False         False         False
# 237  False  False   True  False  False         False         False
# 238  False   True  False  False  False         False         False
# 239  False  False   True  False  False         False         False
# 240  False  False  False   True  False         False         False
# 241  False  False  False   True  False         False         False
# 242  False  False  False   True  False         False         False
# 243  False  False   True  False  False         False         False
# 244  False  False  False   True  False         False         False
# 245  False  False  False   True  False         False         False
# 246  False  False  False  False   True         False         False
# 247  False  False  False   True  False         False         False
# 248  False  False  False   True  False         False         False
# 249  False  False  False  False   True         False         False
# 250  False  False  False   True  False         False         False
# 251  False  False  False   True  False         False         False
# 252  False  False   True  False  False         False         False
# 253  False  False  False   True  False         False          True
# 254  False  False  False   True  False         False         False
# 255  False  False   True  False  False          True         False
# 256  False  False  False   True  False         False         False
# 257  False  False   True  False  False         False         False
# 258  False  False  False  False   True         False         False
# 259  False  False  False  False   True         False         False
# 260  False  False  False  False   True         False         False
# 261  False  False  False   True  False         False          True
# 262  False  False  False   True  False         False         False
#
#      CGPA:9.0-9.5  CGPA:9.5+  CPGA:8.5-9.0   ...     LOR-3  LOR-4  LOR-5  \
# 0           False      False          True   ...     False  False   True
# 1           False      False         False   ...     False   True  False
# 2           False      False          True   ...      True  False  False
# 3            True      False         False   ...      True  False  False
# 4           False      False         False   ...     False   True  False
# 5           False      False          True   ...     False  False   True
# 6            True      False         False   ...     False  False   True
# 7            True      False         False   ...     False  False   True
# 8           False       True         False   ...     False  False   True
# 9           False       True         False   ...     False   True  False
# 10          False       True         False   ...     False  False   True
# 11          False      False          True   ...     False   True  False
# 12          False      False         False   ...     False   True  False
# 13           True      False         False   ...     False  False   True
# 14          False       True         False   ...     False   True  False
# 15          False       True         False   ...     False  False   True
# 16           True      False         False   ...     False  False   True
# 17           True      False         False   ...     False   True  False
# 18           True      False         False   ...     False   True  False
# 19           True      False         False   ...     False   True  False
# 20           True      False         False   ...     False  False   True
# 21          False       True         False   ...     False   True  False
# 22          False      False          True   ...     False  False   True
# 23          False      False         False   ...     False   True  False
# 24          False      False         False   ...     False  False   True
# 25          False      False         False   ...      True  False  False
# 26          False      False         False   ...      True  False  False
# 27           True      False         False   ...     False   True  False
# 28          False       True         False   ...     False  False   True
# 29          False       True         False   ...     False  False   True
# ..            ...        ...           ...   ...       ...    ...    ...
# 233          True      False         False   ...     False  False   True
# 234          True      False         False   ...     False  False   True
# 235          True      False         False   ...     False  False   True
# 236         False       True         False   ...     False  False   True
# 237         False      False          True   ...     False  False   True
# 238          True      False         False   ...     False   True  False
# 239          True      False         False   ...     False  False   True
# 240         False      False          True   ...     False  False   True
# 241          True      False         False   ...     False  False   True
# 242         False       True         False   ...     False   True  False
# 243         False      False          True   ...     False   True  False
# 244          True      False         False   ...     False   True  False
# 245         False      False          True   ...     False  False   True
# 246         False      False          True   ...     False  False   True
# 247         False      False          True   ...     False  False   True
# 248          True      False         False   ...     False   True  False
# 249          True      False         False   ...     False   True  False
# 250          True      False         False   ...     False  False   True
# 251         False      False          True   ...     False   True  False
# 252          True      False         False   ...     False   True  False
# 253         False      False         False   ...      True  False  False
# 254         False      False          True   ...      True  False  False
# 255         False      False         False   ...      True  False  False
# 256          True      False         False   ...     False   True  False
# 257         False      False          True   ...     False   True  False
# 258          True      False         False   ...     False   True  False
# 259         False       True         False   ...     False  False   True
# 260         False       True         False   ...     False  False   True
# 261         False      False         False   ...     False  False   True
# 262          True      False         False   ...     False  False   True
#
#      SOP-2  SOP-3  SOP-4  SOP-5  TOEFL-1  TOEFL-2  TOEFL-3
# 0    False  False   True  False    False     True    False
# 1    False   True  False  False    False     True    False
# 2    False  False   True  False     True    False    False
# 3    False  False  False   True     True    False    False
# 4    False   True  False  False    False     True    False
# 5    False  False   True  False     True    False    False
# 6    False  False   True  False     True    False    False
# 7    False  False  False   True     True    False    False
# 8    False  False  False   True     True    False    False
# 9    False  False   True  False     True    False    False
# 10   False  False  False   True     True    False    False
# 11   False  False  False   True    False     True    False
# 12   False  False   True  False    False     True    False
# 13   False   True  False  False     True    False    False
# 14   False  False   True  False     True    False    False
# 15   False  False   True  False     True    False    False
# 16   False  False  False   True     True    False    False
# 17   False  False  False   True     True    False    False
# 18   False  False  False   True     True    False    False
# 19   False  False  False   True     True    False    False
# 20   False  False   True  False     True    False    False
# 21   False  False  False   True     True    False    False
# 22   False  False   True  False     True    False    False
# 23   False   True  False  False     True    False    False
# 24   False   True  False  False    False    False     True
# 25   False  False   True  False     True    False    False
# 26   False  False   True  False     True    False    False
# 27   False  False  False   True     True    False    False
# 28   False  False  False   True     True    False    False
# 29   False  False  False   True     True    False    False
# ..     ...    ...    ...    ...      ...      ...      ...
# 233  False  False  False   True     True    False    False
# 234  False  False   True  False     True    False    False
# 235  False  False  False   True     True    False    False
# 236  False  False  False   True     True    False    False
# 237  False  False   True  False    False     True    False
# 238  False   True  False  False    False     True    False
# 239  False  False   True  False    False     True    False
# 240  False   True  False  False     True    False    False
# 241  False  False  False   True     True    False    False
# 242  False  False  False   True     True    False    False
# 243  False   True  False  False    False     True    False
# 244  False  False   True  False     True    False    False
# 245  False  False   True  False    False     True    False
# 246  False  False   True  False    False     True    False
# 247  False  False   True  False     True    False    False
# 248  False  False   True  False     True    False    False
# 249  False  False   True  False     True    False    False
# 250  False  False   True  False     True    False    False
# 251  False  False  False   True     True    False    False
# 252  False  False   True  False    False     True    False
# 253  False   True  False  False    False     True    False
# 254  False  False   True  False     True    False    False
# 255  False  False   True  False    False     True    False
# 256  False  False   True  False     True    False    False
# 257  False   True  False  False     True    False    False
# 258  False  False  False   True    False     True    False
# 259  False  False  False   True     True    False    False
# 260  False  False  False   True     True    False    False
# 261  False  False   True  False    False     True    False
# 262  False  False  False   True     True    False    False
#
# [263 rows x 23 columns]
